# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="gas.yaml",
    epochs=10,
    imgsz=416,
    batch=8,
    name="gas_fast_test"
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.207 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.205  Python-3.11.5 torch-2.1.0+cpu CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# ...
